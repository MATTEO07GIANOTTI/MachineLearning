# %%
# !pip install tensorflow matplotlib numpy scikit-learn --user -U
# Out:
# Requirement already satisfied: tensorflow in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (2.13.0)
# Collecting tensorflow
#   Using cached tensorflow-2.13.1-cp38-cp38-win_amd64.whl (1.9 kB)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (3.3.4)
# Collecting matplotlib
#   Using cached matplotlib-3.7.5-cp38-cp38-win_amd64.whl (7.5 MB)
# Requirement already satisfied: numpy in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (1.24.4)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (0.24.1)
# Collecting scikit-learn
#   Using cached scikit_learn-1.3.2-cp38-cp38-win_amd64.whl (9.3 MB)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (20.9)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.1.1-cp38-cp38-win_amd64.whl (477 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (8.2.0)
# Collecting importlib-resources>=3.2.0
#   Using cached importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.57.0-cp38-cp38-win_amd64.whl (1.5 MB)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.15.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.2)
# Requirement already satisfied: scipy>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.6.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (2.1.0)
# Collecting joblib>=1.1.1
#   Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Collecting numpy
#   Using cached numpy-1.22.4-cp38-cp38-win_amd64.whl (14.8 MB)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.25.8)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.31.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.7.4.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.4.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.3.1)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.13.0->tensorflow) (25.9.23)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (52.0.0.post20210125)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.13.0->tensorflow) (18.1.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.4.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.70.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow) (0.36.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.43.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.25.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.4.2)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (5.5.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (8.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.6.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (4.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\net.pc1-18\appdata\roaming\python\python38\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.3.1)
# Installing collected packages: numpy, joblib, importlib-resources, fonttools, contourpy, scikit-learn, matplotlib
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
# Successfully installed contourpy-1.1.1 fonttools-4.57.0 importlib-resources-6.4.5 joblib-1.4.2 matplotlib-3.7.5 numpy-1.22.4 scikit-learn-1.3.2
#   WARNING: The script f2py.exe is installed in 'C:\Users\net.PC1-18\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\net.PC1-18\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

print(tf.__version__) # verifica veloce versione TF
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-822231d10acf> in <module>
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#       3
#       4 import tensorflow as tf
#       5 from tensorflow.keras import layers, models
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\pyplot.py in <module>
#      59 from matplotlib.backend_bases import (
#      60     FigureCanvasBase, FigureManagerBase, MouseButton)
# ---> 61 from matplotlib.figure import Figure, FigureBase, figaspect
#      62 from matplotlib.gridspec import GridSpec, SubplotSpec
#      63 from matplotlib import rcParams, rcParamsDefault, get_backend, rcParamsOrig
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\figure.py in <module>
#      41
#      42 import matplotlib as mpl
# ---> 43 from matplotlib import _blocking_input, backend_bases, _docstring, projections
#      44 from matplotlib.artist import (
#      45     Artist, allow_rasterization, _finalize_rasterization)
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\projections\__init__.py in <module>
#      56 from .geo import AitoffAxes, HammerAxes, LambertAxes, MollweideAxes
#      57 from .polar import PolarAxes
# ---> 58 from mpl_toolkits.mplot3d import Axes3D
#      59
#      60
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\mplot3d\__init__.py in <module>
# ----> 1 from .axes3d import Axes3D
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in <module>
#      26 import matplotlib.scale as mscale
#      27 import matplotlib.transforms as mtransforms
# ---> 28 from matplotlib.axes import Axes, rcParams
#      29 from matplotlib.axes._base import _axis_method_wrapper
#      30 from matplotlib.transforms import Bbox
#
# ImportError: cannot import name 'rcParams' from 'matplotlib.axes' (C:\Users\net.PC1-18\AppData\Roaming\Python\Python38\site-packages\matplotlib\axes\__init__.py)

# %%
# Carica CIFAR-10: (X_train, y_train), (X_test, y_test)
(X_train_full, y_train_full), (X_test_full, y_test_full) = cifar10.load_data()
y_train_full = y_train_full.flatten()
y_test_full = y_test_full.flatten()

# CIFAR-10 label map ufficiale
label_names = ['airplane', 'automobile', 'bird','cat','deer' ,'dog','frog','horse', 'ship', 'truck']
cat_label, dog_label = 3, 5

# Filtra solo gatti e cani
train_mask = (y_train_full == cat_label) | (y_train_full == dog_label)
test_mask = (y_test_full == cat_label) | (y_test_full == dog_label)

X_train_cd = X_train_full[train_mask]
y_train_cd = y_train_full[train_mask]
X_test_cd = X_test_full[test_mask]
y_test_cd = y_test_full[test_mask]

# Rimappa etichette: cat->0, dog->1
y_train_cd = (y_train_cd == dog_label).astype(np.int32)
y_test_cd = (y_test_cd == dog_label).astype(np.int32)

X_train_cd.shape, X_test_cd.shape, np.bincount(y_train_cd), np.bincount(y_test_cd)

# %%
def show_examples(x, y, class_names=('cat', 'dog'), n=12):
    plt.figure(figsize=(10, 4))
    idx = np.random.choice(len(x), size=n, replace=False)
    for i, j in enumerate(idx):
        plt.subplot(2, n//2, i+1)
        plt.imshow(x[j])
        plt.title(class_names[y[j]])
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
# Opzione: riduci il numero di campioni per velocizzare il training in aula
# Imposta a None per usare tutti i dati disponibili
SAMPLES_PER_CLASS_TRAIN = 3000 # es: 3000 cat + 3000 dog = 6000
SAMPLES_PER_CLASS_TEST = 500

def subsample_balanced(X, y, samples_per_class) :
    if samples_per_class is None:
        return X, y
    X_out, y_out = [], []
    for cls in [0,1]:
        idx = np.where(y == cls) [0]
        idx = np.random.choice(idx, size=min(samples_per_class, len(idx) ), replace=False)
        X_out.append(X[idx])
        y_out.append(y[idx] )
    return np.concatenate(X_out), np.concatenate(y_out)

X_train_small, y_train_small = subsample_balanced(X_train_cd, y_train_cd, SAMPLES_PER_CLASS_TRAIN)
X_test_small, y_test_small = subsample_balanced(X_test_cd, y_test_cd, SAMPLES_PER_CLASS_TEST)

# Mescola il training
perm = np. random. permutation(len(X_train_small) )
X_train_small, y_train_small = X_train_small[perm], y_train_small[perm]

# Normalizzazione [0,1]
X_train_small = X_train_small.astype('float32') / 255.0
X_test_small = X_test_small.astype('float32') / 255.0

X_train_small.shape, X_test_small.shape

# %%
def build_cnn(input_shape=(32,32,3)):
    model = models. Sequential( [
        layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=input_shape),
        layers.MaxPooling2D((2,2)),
        layers.Conv2D(64, (3,3), activation='relu', padding='same'),
        layers.MaxPooling2D((2,2)),
        layers.Conv2D(128, (3,3), activation='relu', padding='same'),
        layers.MaxPooling2D((2,2)),
        layers. Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dense(1, activation='sigmoid') # output binario
    ])
    model. compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

model = build_cnn()
model. summary ()

# %%
EPOCHS = 4
history = model.fit(
    X_train_small, y_train_small,
    validation_split=0.1,
    epochs=EPOCHS,
    batch_size=64,
    verbose=1
)

# %%
# Valutazione su test
y_prob = model.predict(X_test_small). ravel()
y_pred = (y_prob >= 0.5).astype(int)

acc = accuracy_score(y_test_small, y_pred)
cm = confusion_matrix(y_test_small, y_pred)

print(f"Accuracy test: {acc :. 3f}")
print("Confusion Matrix (rows=veri, cols=predetti):\n", cm)
print("\nReport:\n", classification_report(y_test_small, y_pred, target_names=['cat','dog'] ) )
